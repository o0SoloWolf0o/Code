# %%
import re
inp = input()
print(re.sub(r'v+', 'w', inp))
# Out:
# bowlet

# %%
def print_n_times(n):
    if n <= 0:
        return ""
    seq = "".join(str(i) for i in range(1, n + 1))
    res = seq * n
    return res
print(print_n_times(int(input())))
# Out:
# 12345678910123456789101234567891012345678910123456789101234567891012345678910123456789101234567891012345678910

# %%
p=lambda n:""if n<=0 else"".join(str(i)for i in range(1,n+1))*n
print(p(int(input())))
# Out:
# 12345678910123456789101234567891012345678910123456789101234567891012345678910123456789101234567891012345678910

# %%
p=lambda n:"".join(map(str,range(1,n+1)))*n
print(p(int(input())))
# Out:
# 12345678910123456789101234567891012345678910123456789101234567891012345678910123456789101234567891012345678910

# %%
n=int(input())
print(''.join(map(str,range(1,n+1)))*n)
# Out:
# 12345678910123456789101234567891012345678910123456789101234567891012345678910123456789101234567891012345678910
